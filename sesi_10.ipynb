# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/property_data.csv')

# %%
df.head()
# Out:
#            PID  ST_NUM    ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0     PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0  LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN  LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0   BERKELEY           12            1      NaN   700
# 4          NaN   203.0   BERKELEY            Y            3        2  1600

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y           --        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PID           8 non-null      float64
#  1   ST_NUM        7 non-null      float64
#  2   ST_NAME       9 non-null      object
#  3   OWN_OCCUPIED  8 non-null      object
#  4   NUM_BEDROOMS  7 non-null      object
#  5   NUM_BATH      8 non-null      object
#  6   SQ_FT         8 non-null      object
# dtypes: float64(2), object(5)
# memory usage: 636.0+ bytes

# %%
missing_values = ["n/a", "na", "--", "NULL"]

# %%
df = pd.read_csv(
    'https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/property_data.csv',
    na_values=missing_values)
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           NaN        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df.isna()
# Out:
#      PID  ST_NUM  ST_NAME  OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0  False   False    False         False         False     False  False
# 1  False   False    False         False         False     False   True
# 2  False    True    False         False          True     False  False
# 3  False   False    False         False         False      True  False
# 4   True   False    False         False         False     False  False
# 5  False   False    False         False          True     False  False
# 6  False    True    False          True         False     False  False
# 7  False   False    False         False          True     False   True
# 8  False   False    False         False          True     False  False

# %%
df.notna()
# Out:
#      PID  ST_NUM  ST_NAME  OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0   True    True     True          True          True      True   True
# 1   True    True     True          True          True      True  False
# 2   True   False     True          True         False      True   True
# 3   True    True     True          True          True     False   True
# 4  False    True     True          True          True      True   True
# 5   True    True     True          True         False      True   True
# 6   True   False     True         False          True      True   True
# 7   True    True     True          True         False      True  False
# 8   True    True     True          True         False      True   True

# %%
~df.isna()
# Out:
#      PID  ST_NUM  ST_NAME  OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0   True    True     True          True          True      True   True
# 1   True    True     True          True          True      True  False
# 2   True   False     True          True         False      True   True
# 3   True    True     True          True          True     False   True
# 4  False    True     True          True          True      True   True
# 5   True    True     True          True         False      True   True
# 6   True   False     True         False          True      True   True
# 7   True    True     True          True         False      True  False
# 8   True    True     True          True         False      True   True

# %%
df[df["ST_NAME"] != "TREMONT"]
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0

# %%
df[~(df["ST_NAME"] == "TREMONT")]
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0

# %%
df.isna()["PID"][4]
# Out:
# True

# %%
print(df.loc[4, "PID"])
print(df.iloc[4, 0])
# Out:
# nan
# nan

# %%
df.loc[4, "PID"] = 100005000.0

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4  100005000.0   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           NaN        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY            N           1.0      NaN   700.0
# 4  100005000.0   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON            N           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           NaN        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df["PID"] = df["PID"].fillna(100005000.0)

# %%
df["OWN_OCCUPIED"] = df["OWN_OCCUPIED"].replace("12", 'N')
df["OWN_OCCUPIED"] = df["OWN_OCCUPIED"].fillna("N")

# %%
df["OWN_OCCUPIED"]
# Out:
# 0    Y
# 1    N
# 2    N
# 3    N
# 4    Y
# 5    Y
# 6    N
# 7    Y
# 8    Y
# Name: OWN_OCCUPIED, dtype: object

# %%
test = "2002/03"
test
# Out:
# '2002/03'

# %%
test[:2] + test[-2:]
# Out:
# '2003'

# %%
obes["Year"].str[:2] + obes["Year"].str[-2:]
# Out:
# 0     2003
# 1     2004
# 2     2005
# 3     2006
# 4     2007
# 5     2008
# 6     2009
# 7     2010
# 8     2011
# 9     2012
# 10    2013
# Name: Year, dtype: object

# %%
# Out:
# 0     2003
# 1     2004
# 2     2005
# 3     2006
# 4     2007
# 5     2008
# 6     2009
# 7     2010
# 8     2011
# 9     2012
# 10    2013
# Name: Year, dtype: object

# %%
obes = pd.read_excel("data/obes.xls", sheet_name="7.2", skiprows=[0,1,2,3,5], skipfooter=14)
obes = obes.rename(columns={"Unnamed: 0": "Year"})
obes["Year"] = obes["Year"].map(lambda x: x[:2] + x[-2:])

obes
# Out:
#        Year  Total  Under 16  16-24  25-34  35-44  45-54  55-64  65-74  \
# 0   2002/03   1275       400     65    136    289    216     94     52
# 1   2003/04   1711       579     67    174    391    273    151     52
# 2   2004/05   2035       547    107    287    487    364    174     36
# 3   2005/06   2564       583     96    341    637    554    258     72
# 4   2006/07   3862       656    184    461   1069    872    459    118
# 5   2007/08   5018       747    228    564   1469   1198    598    157
# 6   2008/09   7988       775    322   1013   2359   2133   1099    221
# 7   2009/10  10571       632    361   1348   3132   3076   1555    378
# 8   2010/11  11574       525    375   1425   3277   3573   1820    456
# 9   2011/12  11736       495    391   1484   3104   3581   2119    468
# 10  2012/13  10957       556    356   1437   2744   3305   1965    495
#
#     75 and over
# 0            23
# 1            24
# 2            32
# 3            20
# 4            43
# ...

# %%
obes = obes.set_index(keys="Year")

# %%
obes
# Out:
#       Total  Under 16  16-24  25-34  35-44  45-54  55-64  65-74  75 and over
# Year
# 2003   1275       400     65    136    289    216     94     52           23
# 2004   1711       579     67    174    391    273    151     52           24
# 2005   2035       547    107    287    487    364    174     36           32
# 2006   2564       583     96    341    637    554    258     72           20
# 2007   3862       656    184    461   1069    872    459    118           43
# 2008   5018       747    228    564   1469   1198    598    157           53
# 2009   7988       775    322   1013   2359   2133   1099    221           63
# 2010  10571       632    361   1348   3132   3076   1555    378           87
# 2011  11574       525    375   1425   3277   3573   1820    456          115
# 2012  11736       495    391   1484   3104   3581   2119    468           94
# 2013  10957       556    356   1437   2744   3305   1965    495           99

# %%
# %matplotlib inline
obes.plot()
# Out:
# <Axes: xlabel='Year'>

# %%
data_age_minus_total = obes.drop('Total', axis=1)

# %%
data_age_minus_total.plot()
# Out:
# <Axes: xlabel='Year'>

# %%
data_age = obes

# %%
data_age['Under 16'].plot(label="Under 16", legend=True)
data_age['35-44'].plot(label="35-44", legend=True)
# Out:
# <Axes: xlabel='Year'>

# %%
date_rng = pd.date_range(start='1/01/2020', end='1/08/2020', freq='H')

date_rng
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 01:00:00',
#                '2020-01-01 02:00:00', '2020-01-01 03:00:00',
#                '2020-01-01 04:00:00', '2020-01-01 05:00:00',
#                '2020-01-01 06:00:00', '2020-01-01 07:00:00',
#                '2020-01-01 08:00:00', '2020-01-01 09:00:00',
#                ...
#                '2020-01-07 15:00:00', '2020-01-07 16:00:00',
#                '2020-01-07 17:00:00', '2020-01-07 18:00:00',
#                '2020-01-07 19:00:00', '2020-01-07 20:00:00',
#                '2020-01-07 21:00:00', '2020-01-07 22:00:00',
#                '2020-01-07 23:00:00', '2020-01-08 00:00:00'],
#               dtype='datetime64[ns]', length=169, freq='H')

# %%
df = pd.DataFrame(date_rng, columns=['date'])
df['data'] = np.random.randint(0,100,size=(len(date_rng)))

# %%
df
# Out:
#                    date  data
# 0   2020-01-01 00:00:00    64
# 1   2020-01-01 01:00:00    82
# 2   2020-01-01 02:00:00    56
# 3   2020-01-01 03:00:00     6
# 4   2020-01-01 04:00:00    32
# ..                  ...   ...
# 164 2020-01-07 20:00:00    90
# 165 2020-01-07 21:00:00    11
# 166 2020-01-07 22:00:00    55
# 167 2020-01-07 23:00:00     1
# 168 2020-01-08 00:00:00    29
#
# [169 rows x 2 columns]

# %%
df['datetime'] = pd.to_datetime(df['date'])

df
# Out:
#                    date  data            datetime
# 0   2020-01-01 00:00:00    64 2020-01-01 00:00:00
# 1   2020-01-01 01:00:00    82 2020-01-01 01:00:00
# 2   2020-01-01 02:00:00    56 2020-01-01 02:00:00
# 3   2020-01-01 03:00:00     6 2020-01-01 03:00:00
# 4   2020-01-01 04:00:00    32 2020-01-01 04:00:00
# ..                  ...   ...                 ...
# 164 2020-01-07 20:00:00    90 2020-01-07 20:00:00
# 165 2020-01-07 21:00:00    11 2020-01-07 21:00:00
# 166 2020-01-07 22:00:00    55 2020-01-07 22:00:00
# 167 2020-01-07 23:00:00     1 2020-01-07 23:00:00
# 168 2020-01-08 00:00:00    29 2020-01-08 00:00:00
#
# [169 rows x 3 columns]

# %%
df = df.set_index('datetime')

# %%
df
# Out:
#                                    date  data
# datetime
# 2020-01-01 00:00:00 2020-01-01 00:00:00    64
# 2020-01-01 01:00:00 2020-01-01 01:00:00    82
# 2020-01-01 02:00:00 2020-01-01 02:00:00    56
# 2020-01-01 03:00:00 2020-01-01 03:00:00     6
# 2020-01-01 04:00:00 2020-01-01 04:00:00    32
# ...                                 ...   ...
# 2020-01-07 20:00:00 2020-01-07 20:00:00    90
# 2020-01-07 21:00:00 2020-01-07 21:00:00    11
# 2020-01-07 22:00:00 2020-01-07 22:00:00    55
# 2020-01-07 23:00:00 2020-01-07 23:00:00     1
# 2020-01-08 00:00:00 2020-01-08 00:00:00    29
#
# [169 rows x 2 columns]

# %%
df = df.drop(columns="date")

# %%
df
# Out:
#                      data
# datetime
# 2020-01-01 00:00:00    64
# 2020-01-01 01:00:00    82
# 2020-01-01 02:00:00    56
# 2020-01-01 03:00:00     6
# 2020-01-01 04:00:00    32
# ...                   ...
# 2020-01-07 20:00:00    90
# 2020-01-07 21:00:00    11
# 2020-01-07 22:00:00    55
# 2020-01-07 23:00:00     1
# 2020-01-08 00:00:00    29
#
# [169 rows x 1 columns]

# %%
obes["Year"]
# Out:
# 0     2002/03
# 1     2003/04
# 2     2004/05
# 3     2005/06
# 4     2006/07
# 5     2007/08
# 6     2008/09
# 7     2009/10
# 8     2010/11
# 9     2011/12
# 10    2012/13
# Name: Year, dtype: object
