# %%
import pandas as pd
import numpy as np

# %%
df_can = pd.read_excel('https://github.com/ardhiraka/PFDS_sources/blob/master/Canada.xlsx?raw=true',
                       sheet_name='Canada by Citizenship',
                       skiprows=range(20),
                       skipfooter=2)

print ('Data read into a pandas dataframe!')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/nikki/workspace/bni/sesi_11.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/nikki/workspace/bni/sesi_11.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df_can = pd.read_excel('https://github.com/ardhiraka/PFDS_sources/blob/master/Canada.xlsx?raw=true',
#       <a href='vscode-notebook-cell:/Users/nikki/workspace/bni/sesi_11.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a>                        sheet_name='Canada by Citizenship',
#       <a href='vscode-notebook-cell:/Users/nikki/workspace/bni/sesi_11.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a>                        skiprows=range(20),
#       <a href='vscode-notebook-cell:/Users/nikki/workspace/bni/sesi_11.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a>                        skipfooter=2)
# ...

# %%
df_can.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 43 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Type      195 non-null    object
#  1   Coverage  195 non-null    object
#  2   OdName    195 non-null    object
#  3   AREA      195 non-null    int64
#  4   AreaName  195 non-null    object
#  5   REG       195 non-null    int64
#  6   RegName   195 non-null    object
#  7   DEV       195 non-null    int64
#  8   DevName   195 non-null    object
#  9   1980      195 non-null    int64
#  10  1981      195 non-null    int64
#  11  1982      195 non-null    int64
#  12  1983      195 non-null    int64
#  13  1984      195 non-null    int64
#  14  1985      195 non-null    int64
#  15  1986      195 non-null    int64
#  16  1987      195 non-null    int64
#  17  1988      195 non-null    int64
#  18  1989      195 non-null    int64
#  19  1990      195 non-null    int64
# ...

# %%
df_can.shape
# Out:
# (195, 43)

# %%
df_can.isna().sum()[df_can.isna().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df_asia = df_can[df_can["Continent"] == "Asia"]
df_asia.to_excel("data/canada_asia.xlsx")

# %%
df_can.columns.values
# Out:
# array(['Type', 'Coverage', 'OdName', 'AREA', 'AreaName', 'REG', 'RegName',
#        'DEV', 'DevName', 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012, 2013], dtype=object)

# %%
new_columns = []
for col in df_can.columns.values:
    new_columns.append(str(col))
np.array(new_columns)
# Out:
# array(['Type', 'Coverage', 'OdName', 'AREA', 'AreaName', 'REG', 'RegName',
#        'DEV', 'DevName', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013'], dtype='<U8')

# %%
str(df_can.columns.values)
# Out:
# "['Type' 'Coverage' 'OdName' 'AREA' 'AreaName' 'REG' 'RegName' 'DEV'\n 'DevName' 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991\n 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005\n 2006 2007 2008 2009 2010 2011 2012 2013]"

# %%
df_can.columns = np.array([*map(str, df_can.columns.values)])
df_can.columns
# Out:
# Index(['Type', 'Coverage', 'OdName', 'AREA', 'AreaName', 'REG', 'RegName',
#        'DEV', 'DevName', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013'],
#       dtype='object')

# %%
df_can.describe()
# Out:
#              AREA          REG         DEV          1980          1981  \
# count  195.000000   195.000000  195.000000    195.000000    195.000000
# mean   912.764103  1249.015385  901.753846    508.394872    566.989744
# std     13.082835  1185.526885    0.431878   1949.588546   2152.643752
# min    903.000000   905.000000  901.000000      0.000000      0.000000
# 25%    903.000000   914.000000  902.000000      0.000000      0.000000
# 50%    908.000000   922.000000  902.000000     13.000000     10.000000
# 75%    922.000000   925.500000  902.000000    251.500000    295.500000
# max    935.000000  5501.000000  902.000000  22045.000000  24796.000000
#
#                1982          1983          1984         1985         1986  \
# count    195.000000    195.000000    195.000000   195.000000   195.000000
# mean     534.723077    387.435897    376.497436   358.861538   441.271795
# std     1866.997511   1204.333597   1198.246371  1079.309600  1225.576630
# ...

# %%
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df_can = df_can.drop(columns=["AREA", "REG", "DEV"])

# %%
# select AREA, AreaName, count(distinct AreaName)
# from df_can
# group by AREA, AreaName

# AREA, AreaName, Count
# 935, Asia, 1
# 935, Europe, 1

df_can.groupby(by=["AREA", "AreaName"])["OdName"].count()
# Out:
# AREA  AreaName
# 903   Africa                             54
# 904   Latin America and the Caribbean    33
# 905   Northern America                    2
# 908   Europe                             43
# 909   Oceania                            14
# 935   Asia                               49
# Name: OdName, dtype: int64

# %%
df_can = df_can.rename(columns={"OdName": "Country", "AreaName": "Continent", 'RegName':'Region'})

# %%
df_can[["Country", "1980", "1981", "1982"]]
# Out:
#             Country  1980  1981  1982
# 0       Afghanistan    16    39    39
# 1           Albania     1     0     0
# 2           Algeria    80    67    71
# 3    American Samoa     0     1     0
# 4           Andorra     0     0     0
# ..              ...   ...   ...   ...
# 190        Viet Nam  1191  1829  2162
# 191  Western Sahara     0     0     0
# 192           Yemen     1     2     1
# 193          Zambia    11    17    11
# 194        Zimbabwe    72   114   102
#
# [195 rows x 4 columns]

# %%
df_can.iloc[0:4]
# Out:
#          Type    Coverage         Country Continent           Region  \
# 0  Immigrants  Foreigners     Afghanistan      Asia    Southern Asia
# 1  Immigrants  Foreigners         Albania    Europe  Southern Europe
# 2  Immigrants  Foreigners         Algeria    Africa  Northern Africa
# 3  Immigrants  Foreigners  American Samoa   Oceania        Polynesia
#
#               DevName  1980  1981  1982  1983  ...  2004  2005  2006  2007  \
# 0  Developing regions    16    39    39    47  ...  2978  3436  3009  2652
# 1   Developed regions     1     0     0     0  ...  1450  1223   856   702
# 2  Developing regions    80    67    71    69  ...  3616  3626  4807  3623
# 3  Developing regions     0     1     0     0  ...     0     0     1     0
#
#    2008  2009  2010  2011  2012  2013
# 0  2111  1746  1758  2203  2635  2004
# 1   560   716   561   539   620   603
# 2  4005  5393  4752  4325  3774  4331
# 3     0     0     0     0     0     0
#
# [4 rows x 40 columns]

# %%
df_can.loc[0:4]
# Out:
#          Type    Coverage         Country Continent           Region  \
# 0  Immigrants  Foreigners     Afghanistan      Asia    Southern Asia
# 1  Immigrants  Foreigners         Albania    Europe  Southern Europe
# 2  Immigrants  Foreigners         Algeria    Africa  Northern Africa
# 3  Immigrants  Foreigners  American Samoa   Oceania        Polynesia
# 4  Immigrants  Foreigners         Andorra    Europe  Southern Europe
#
#               DevName  1980  1981  1982  1983  ...  2004  2005  2006  2007  \
# 0  Developing regions    16    39    39    47  ...  2978  3436  3009  2652
# 1   Developed regions     1     0     0     0  ...  1450  1223   856   702
# 2  Developing regions    80    67    71    69  ...  3616  3626  4807  3623
# 3  Developing regions     0     1     0     0  ...     0     0     1     0
# 4   Developed regions     0     0     0     0  ...     0     0     1     1
#
#    2008  2009  2010  2011  2012  2013
# 0  2111  1746  1758  2203  2635  2004
# ...

# %%
df_can.loc[:, "1980":"1985"]
# Out:
#      1980  1981  1982  1983  1984  1985
# 0      16    39    39    47    71   340
# 1       1     0     0     0     0     0
# 2      80    67    71    69    63    44
# 3       0     1     0     0     0     0
# 4       0     0     0     0     0     0
# ..    ...   ...   ...   ...   ...   ...
# 190  1191  1829  2162  3404  7583  5907
# 191     0     0     0     0     0     0
# 192     1     2     1     6     0    18
# 193    11    17    11     7    16     9
# 194    72   114   102    44    32    29
#
# [195 rows x 6 columns]

# %%
df_can.columns
# Out:
# Index(['Type', 'Coverage', 'Country', 'Continent', 'Region', 'DevName', '1980',
#        '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013'],
#       dtype='object')

# %%
df_can.columns = np.concatenate([df_can.columns.values[:6], [*map(int, df_can.columns.values[6:])]])

# %%
wilayah = wilayah 2
stop = 1990

["Country"] + [*map(str, [*range(start, stop)])]
# Out:
# ['Country',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989']

# %%
start = 1980
stop = 1990

df_can_1980 = df_can[['Country'] + [*range(start, stop)]]

# %%
df_can = df_can.set_index("Country")
df_can_1980 = df_can_1980.set_index("Country")

# %%
df_can_1980.loc["Haiti"]
# Out:
# 1980    1666
# 1981    3692
# 1982    3498
# 1983    2860
# 1984    1418
# 1985    1321
# 1986    1753
# 1987    2132
# 1988    1829
# 1989    2377
# Name: Haiti, dtype: int64

# %%
df_can_1980.loc["Haiti"].plot(kind="line")
# Out:
# <Axes: ylabel='Density'>
